# %%
			#import library
import numpy as np
import os
import math
from matplotlib import pyplot as plt
# %matplotlib inline
import cv2

# %%
			#Taking picture

webcam =cv2.VideoCapture(0)
ret, frame=webcam.read()
print (ret)
webcam.release()  #close the webcam
# Out:
# True

# %%
	#opening in window
cv2.startWindowThread()
cv2.namedWindow("Picture Window",cv2.WINDOW_NORMAL)
cv2.imshow("Picture Window",frame)
cv2.waitKey()
cv2.destroyAllWindows()

# %%
#open in window and print in browser

cv2.namedWindow("Picture Window",cv2.WINDOW_AUTOSIZE)
cv2.imshow("Picture Window",frame)
cv2.waitKey()
cv2.destroyAllWindows()
plt.imshow(frame)
plt.show()

# %%
# BGR --->>>> RGB
#opencv takes picture in BGR.For better quality we have to convert it to RGB

frame_RGB = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
plt.imshow(frame_RGB)
plt.axis("off")
plt.show()

# %%
#Write or save picture on pc

#Write in GBR OR RGB
cv2.imwrite('C:/Users/Razib Hossain/Desktop/CSE 299 (git)/Face-Recognition-From-Live-Videos-CSE-299-/Razib_picture_GBR.jpg',frame)  #on pc the path show '\' in this but we have to change it to '/'
cv2.imwrite('C:/Users/Razib Hossain/Desktop/CSE 299 (git)/Face-Recognition-From-Live-Videos-CSE-299-/Razib_picture_RGB.jpg',frame_RGB)
os.system("nautilus images")
# Out:
# 1

# %%
#Read Picture from pc
#Read In GBR or RGB
read_mode=1 	#or 0 or 2
picture_GBR=cv2.imread('C:/Users/Razib Hossain/Desktop/CSE 299 (git)/Face-Recognition-From-Live-Videos-CSE-299-/demo.jpg',read_mode)
picture_RGB=cv2.imread('C:/Users/Razib Hossain/Desktop/CSE 299 (git)/Face-Recognition-From-Live-Videos-CSE-299-/demo.jpg',read_mode)

# %%
#Show read picture on browser


#numpy intervention
picture=np.hstack((picture_GBR,picture_RGB))
plt.axis("off")
plt.title("GBR RGB")
plt.imshow(picture,cmap="Greys_r")
plt.show()

# %%
cap = cv2.VideoCapture(0)

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Display the resulting frame
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-6-8bff37fb5508> in <module>
# ----> 1 cap = cv2.VideoCapture(0)
#       2
#       3 while(True):
#       4     # Capture frame-by-frame
#       5     ret, frame = cap.read()
#
# NameError: name 'cv2' is not defined

# %%
#Write Video

cap = cv2.VideoCapture(0)

# Define the codec and create VideoWriter object
fourcc = cv2.VideoWriter_fourcc(*'XVID')
out = cv2.VideoWriter('DemoVideo.avi',fourcc, 20.0, (640,480))

while(cap.isOpened()):
    ret, frame = cap.read()
    if ret==True:
        frame = cv2.flip(frame,1)

        # write the flipped frame
        out.write(frame)

        cv2.imshow('frame',frame)
        if cv2.waitKey(1) & 0xFF == ord('q'):
            break
    else:
        break

# Release everything if job is finished
cap.release()
out.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-7-1e9491561cbc> in <module>
#       1 #Write Video
#       2
# ----> 3 cap = cv2.VideoCapture(0)
#       4
#       5 # Define the codec and create VideoWriter object
#
# NameError: name 'cv2' is not defined

# %%
#Read Video

cap = cv2.VideoCapture('Demoavi.avi')

while(cap.isOpened()):
    ret, frame = cap.read()

    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# error                                     Traceback (most recent call last)
# <ipython-input-6-d96b33e0a9c6> in <module>
#       6     ret, frame = cap.read()
#       7
# ----> 8     gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)
#       9
#      10     cv2.imshow('frame',gray)
#
# error: OpenCV(3.4.1) C:\Miniconda3\conda-bld\opencv-suite_1533128839831\work\modules\imgproc\src\color.cpp:11147: error: (-215) scn == 3 || scn == 4 in function cv::cvtColor

# %%
#Draw a recangle on live video

cap = cv2.VideoCapture(0)

while(True):
    # Capture frame-by-frame
    ret, frame = cap.read()

    # Our operations on the frame come here
    gray = cv2.cvtColor(frame, cv2.COLOR_BGR2GRAY)

    # Display the resulting frame
    cv2.imshow('frame',gray)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break

# When everything done, release the capture
cap.release()
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-391d691a0cbd> in <module>
#       1 #Draw a recangle on live video
#       2
# ----> 3 cap = cv2.VideoCapture(0)
#       4
#       5 while(True):
#
# NameError: name 'cv2' is not defined
