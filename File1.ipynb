# %%
			#import library
import numpy as np
import os
import math
from matplotlib import pyplot as plt
# %matplotlib inline
import cv2

# %%
webcam=cv2.VideoCapture(0)
__,frame=webcam.read()
cv2.waitkey(1000)
__,frame=webcam.read()
webcam.release()
plt_show(frame)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-6-e8e36147b79c> in <module>
#       1 webcam=cv2.VideoCapture(0)
#       2 __,frame=webcam.read()
# ----> 3 cv2.waitkey(1000)
#       4 __,frame=webcam.read()
#       5 webcam.release()
#
# AttributeError: module 'cv2' has no attribute 'waitkey'

# %%
webcam =cv2.VideoCapture(0)
ret, frame=webcam.read()
print (ret)
webcam.release()  #close the webcam
# Out:
# True

# %%
cv2.namedWindow("Python Data Tutorial",cv2.WINDOW_AUTOSIZE)
cv2.imshow("Pydata tutorial",frame)
cv2.waitKey()
cv2.destroyAllWindows()
plt.imshow(frame)
plt.show()

# %%
# BGR --->>>> RGB

#From BGR to RGB

#pixel color conversion
frame_RGB = cv2.cvtColor(frame,cv2.COLOR_BGR2RGB)
plt.imshow(frame_RGB)
#lET'S TAKE THOSE UGLEY TICKS OFF
plt.axis("off")
plt.show()

# %%
#Write or save picture on pc

#Write in GBR OR RGB
cv2.imwrite('C:/299/Razib_picture_GBR.jpg',frame)  #on pc the path show '\' in this but we have to change it to '/'
cv2.imwrite('C:/299/Razib_picture_RGB.jpg',frame_RGB)
os.system("nautilus images")
# Out:
# 1

# %%
#face_cascade=cv2.CasecadeClassifier('haarcascade_frontalcatface.xml')
#detector=cv2.CascadeClassifier("xml/haarcascade_frontalcatface.xml")

# %%
detector=cv2.CascadeClassifier("haarcascade_frontalcatface.xml")
scale_factor=1.2
min_neighbors=5
min_size=(30, 30)
biggest_only=True
flags=cv2.CASCADE_FIND_BIGGEST_OBJECT |  \
          cv2.CASCADE_DO_ROUGH_SEARCH if biggest_only else \
          cv2.CASCADE_SCALE_IMAGE
faces_coord=detector.detectMultiScale(frame,
                                      scaleFactor=scale_factor,
                                      minNeighbors=min_neighbors,
                                      minSize=min_size,
                                      flags=flags)

print("Type: "+ str(type(faces_coord)))
print (faces_coord)
print("Length: " + str(len(faces_coord)))
# Out:
# Type: <class 'tuple'>
# ()
# Length: 0

# %%
for(x,y,w,h) in faces_coord:
    cv2.rectangle(frame,(x,y),(x+w,y+h),(150,150,0),8)
plt.show(frame)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-13-b735323ec5e6> in <module>
#       1 for(x,y,w,h) in faces_coord:
#       2     cv2.rectangle(frame,(x,y),(x+w,y+h),(150,150,0),8)
# ----> 3 plt.show(frame)
#
# ~\Anaconda3299\lib\site-packages\matplotlib\pyplot.py in show(*args, **kw)
#     252     """
#     253     global _show
# --> 254     return _show(*args, **kw)
#     255
#     256
#
# ~\Anaconda3299\lib\site-packages\ipykernel\pylab\backend_inline.py in show(close, block)
#      43         # only call close('all') if any to close
#      44         # close triggers gc.collect, which can be slow
# ---> 45         if close and Gcf.get_all_fig_managers():
#      46             matplotlib.pyplot.close('all')
#      47
#
# ValueError: The truth value of an array with more than one element is ambiguous. Use a.any() or a.all()
